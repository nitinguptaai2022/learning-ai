# %%
"""
1. Go to website
2. Search for a respective product
3. Try to locate review part
4. Scrap all data into local system
"""
# Out:
# '\n1. Go to website\n2. Search for a respective product\n3. Try to locate review part\n4. Scrap all data into local system\n'

# %%
from flask import Flask, render_template, request,jsonify
from flask_cors import CORS,cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18940/1629226948.py in <module>
#       1 from flask import Flask, render_template, request,jsonify
# ----> 2 from flask_cors import CORS,cross_origin
#       3 import requests
#       4 from bs4 import BeautifulSoup as bs
#       5 from urllib.request import urlopen as uReq
#
# ModuleNotFoundError: No module named 'flask_cors'

# %%
pip install -r C:\Users\ngupta\classes-ai\ReviewFlask\requirements.txt
# Out:
# ...
#   Using cached beautifulsoup4-4.9.1-py3-none-any.whl (115 kB)
# ...
#   Using cached bs4-0.0.1.tar.gz (1.1 kB)
# ...
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# ...
#   Using cached click-7.1.2-py2.py3-none-any.whl (82 kB)
# ...
#   Using cached Flask_Cors-3.0.9-py2.py3-none-any.whl (14 kB)
# ...
#   Using cached gunicorn-20.0.4-py2.py3-none-any.whl (77 kB)
# ...
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# ...
#   Using cached itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# ...
#   Using cached Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
# ...
#   Using cached requests-2.24.0-py2.py3-none-any.whl (61 kB)
# ...
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# ...
#   Using cached soupsieve-2.0.1-py3-none-any.whl (32 kB)
# ...
#   Using cached urllib3-1.25.10-py2.py3-none-any.whl (127 kB)
# ...
#   Using cached Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1271 sha256=ba3b5254612e51fae96b428772048868f714bf15dcafa31d98f44ee4251fb262
# ...

# %%
from flask import Flask, render_template, request,jsonify
from flask_cors import CORS,cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
searchString = "iphone7"
flipkart_url = "https://www.flipkart.com/search?q=" + searchString

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone7'

# %%
uClient = uReq(flipkart_url)

# %%
uClient

# %%
flipkartPage = uClient.read()

# %%
flipkartPage
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app_modules.chunk.94b5e7.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.4f01cc.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/a
# ...

# %%
uClient.close()

# %%
flipkart_html = bs(flipkartPage, "html.parser")

# %%
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
bigboxes = flipkart_html.findAll("div", {"class": "_1AtVbE col-12-12"})

# %%
bigboxes
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=iphone7&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=tyy,
# ...

# %%
del bigboxes[0:3]

# %%
box = bigboxes[0]

# %%
box
# Out:
# <div class="_1AtVbE col-12-12"><div class="_13oc-S"><div data-id="MOBEMK62JSRHU85T" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/apple-iphone-7-rose-gold-32-gb/p/itmen6dapsvxanrk?pid=MOBEMK62JSRHU85T&amp;lid=LSTMOBEMK62JSRHU85TIU9DKW&amp;marketplace=FLIPKART&amp;q=iphone7&amp;store=tyy%2F4io&amp;srno=s_1_2&amp;otracker=search&amp;fm=organic&amp;iid=d6118744-f510-47ff-b228-a7f951f26107.MOBEMK62JSRHU85T.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=m79po1p16o0000001649483573485&amp;qH=c848b7081ba96a14" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="APPLE iPhone 7 (Rose Gold, 32 GB)" class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/312/312/k12go7k0/mobile/e/y/z/apple-iphone-7-mn952hn-a-original-imafkqe8ptsnpd6m.jpeg?q=70"/></div></div><div class="_3G6awp"><span class="_192laR">Currently unavailable</span></div></div><div class="_3wLduG"><div class="_3
# ...

# %%
productLink = "https://www.flipkart.com" + box.div.div.div.a['href']

# %%
box.div.div.div.a
# Out:
# <a class="_1fQZEK" href="/apple-iphone-7-rose-gold-32-gb/p/itmen6dapsvxanrk?pid=MOBEMK62JSRHU85T&amp;lid=LSTMOBEMK62JSRHU85TIU9DKW&amp;marketplace=FLIPKART&amp;q=iphone7&amp;store=tyy%2F4io&amp;srno=s_1_2&amp;otracker=search&amp;fm=organic&amp;iid=d6118744-f510-47ff-b228-a7f951f26107.MOBEMK62JSRHU85T.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=m79po1p16o0000001649483573485&amp;qH=c848b7081ba96a14" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="APPLE iPhone 7 (Rose Gold, 32 GB)" class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/312/312/k12go7k0/mobile/e/y/z/apple-iphone-7-mn952hn-a-original-imafkqe8ptsnpd6m.jpeg?q=70"/></div></div><div class="_3G6awp"><span class="_192laR">Currently unavailable</span></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny">
# ...

# %%
prodRes = requests.get(productLink)

# %%
prodRes.encoding='utf-8'

# %%
prod_html = bs(prodRes.text, "html.parser")

# %%
prod_html
# Out:
# <!DOCTYPE html>
# ...

# %%
print(prod_html)
# Out:
# <!DOCTYPE html>
# ...

# %%
commentboxes = prod_html.find_all('div', {'class': "_16PBlm"})

# %%
commentboxes
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Worth every penny</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Thank u Flipkart for your fast delivery. It is awesome and very very nice.I like this very much.</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-201909/blobio-imr-201909_bb63f44c74f24bd3a46d806bfe7b7d01.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-201909/blobio-imr-201909_c076f56308954ddba89a8f889c733848.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR
# ...

# %%
len(commentboxes)
# Out:
# 11

# %%
commentboxes[0].div.div
# Out:
# <div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Worth every penny</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Thank u Flipkart for your fast delivery. It is awesome and very very nice.I like this very much.</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-201909/blobio-imr-201909_bb63f44c74f24bd3a46d806bfe7b7d01.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-201909/blobio-imr-201909_c076f56308954ddba89a8f889c733848.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH">Hemanta Sa</p><svg class="_2a
# ...

# %%
commentboxes[0].div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text
# Out:
# 'Hemanta Sa'

# %%
commentboxes[0].div.div.div.div.text
# Out:
# '5'

# %%
for commentbox in commentboxes:
        #name.encode(encoding='utf-8')
        name = commentbox.div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text
        print(name)
# Out:
# Hemanta Sa
# Anish Singh
# suresh b
# Gautam Choudhary
# Flipkart Customer
# Mayank Chaube
# Shariq Ahmad Beigh
# chandan kumar panda
# Preeti Kureel
# Vikas Mehta
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18940/1847815032.py in <module>
#       1 for commentbox in commentboxes:
#       2         #name.encode(encoding='utf-8')
# ----> 3         name = commentbox.div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text
#       4         print(name)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
for i in range(len(commentboxes)-1):
        #name.encode(encoding='utf-8')
        print(commentboxes[i].div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text)
        print(commentboxes[i].div.div.div.div.text)
        print(commentboxes[i].div.div.div.p.text)
        comtag = commentboxes[i].div.div.find_all('div', {'class': ''})
        print(comtag[0].div.text)
        print("\n")
# Out:
# Hemanta Sa
# 5
# Worth every penny
# Thank u Flipkart for your fast delivery. It is awesome and very very nice.I like this very much.
#
#
# Anish Singh
# 5
# Simply awesome
# My first iPhone ❤️Got 3 days before expected delivery date. Thank you Flipkart.Phone is looking so classy, handy & beautiful.It's a black beauty. Sound & display quality is awesome .For best music experience use your Apple headphones, which you will get with box.Loved it ❤️
#
#
# suresh b
# 4
# Pretty good
# excellent phone camera is very nice and the stereo speakers are fantastic it gives you cinematic experience with the cool retaina display .Blindly go for it value for money .
#
#
# Gautam Choudhary
# 5
# Worth every penny
# Awesome Smartphone for iPhone lover..I got it during The Big Billion Day Sale..Camera Quality AwesomePerformance is SuperbGood Display Beautiful Looking Battery performs is minus point as per trend it is not as much sufficient but not too bad..Really love it ?????Thank you Flipkart..????
# ...

# %%
"""Todays task
1. Goto ineuron.ai
2. List down all the courses
3. One by one scrap all the course page
4. Collect all the data segment wise (like course name, description , price, mentor etc.)
5. Store this data into mysql or mongo DB
6. Deploy it on herokuapp, aws, gcp
6. Share deploy link
7. Optional - Create a UI and showcase in html
"""
