# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#1 . Find out how many male and female passenger was onboarded .
df["Sex"]
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
df["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
len(df[df["Sex"]=="male"])
# Out:
# 577

# %%
df.groupby('Sex').count()
# Out:
#         PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# female          314       314     314   314  261    314    314     314   314
# male            577       577     577   577  453    577    577     577   577
#
#         Cabin  Embarked
# Sex
# female     97       312
# male      107       577

# %%
df.groupby('Sex')['Sex'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %%
#2. how many survived we have .
df['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df[df['Survived']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(df[df['Survived']==1])
# Out:
# 342

# %%
#3. how many casuality we have 
len(df[df['Survived']==0])
# Out:
# 549

# %%
#4 . what is name of a person who is the eldest one . 
df['Age'] == df['Age'].max()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df[df['Age'] == df['Age'].max()]['Name']
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
#5 . how many passenger do we have in first , second and third class 
df.groupby('Pclass')

# %%
df.groupby('Pclass').count()
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               216       216   216  216  186    216    216     216   216
# 2               184       184   184  184  173    184    184     184   184
# 3               491       491   491  491  355    491    491     491   491
#
#         Cabin  Embarked
# Pclass
# 1         176       214
# 2          16       184
# 3          12       491

# %%
df.groupby('Pclass')['Pclass'].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %%
#6. how many person we have whose name starts with "s"
df['Name'].str.startswith("S")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Name, Length: 891, dtype: bool

# %%
df[df['Name'].str.startswith("S")]
# Out:
#      PassengerId  Survived  Pclass  \
# 10            11         1       3
# 12            13         0       3
# 23            24         1       1
# 31            32         1       1
# 48            49         0       3
# ..           ...       ...     ...
# 851          852         0       3
# 862          863         1       1
# 863          864         0       3
# 880          881         1       2
# 884          885         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 48                                 Samaan, Mr. Youssef    male   NaN      2
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Name'].str.startswith("S")]['Name']
# Out:
# 10                       Sandstrom, Miss. Marguerite Rut
# 12                        Saundercock, Mr. William Henry
# 23                          Sloper, Mr. William Thompson
# 31        Spencer, Mrs. William Augustus (Marie Eugenie)
# 48                                   Samaan, Mr. Youssef
#                              ...
# 851                                  Svensson, Mr. Johan
# 862    Swift, Mrs. Frederick Joel (Margaret Welles Ba...
# 863                    Sage, Miss. Dorothy Edith "Dolly"
# 880         Shelley, Mrs. William (Imanita Parrish Hall)
# 884                               Sutehall, Mr. Henry Jr
# Name: Name, Length: 86, dtype: object

# %%
#7. try to create a new column which is a summation  of "SibSp" and "parch"
df['MyNewColumn']=df['SibSp'] + df['Parch']

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  MyNewColumn
# 0      0         A/5 21171   7.2500   NaN        S            1
# 1      0          PC 17599  71.2833   C85        C            1
# 2      0  STON/O2. 3101282   7.9250   NaN        S            0
# ...

# %%
#8 . how many person do we have below age of 25 .
len(df[df['Age'] < 25])
# Out:
# 278

# %%
#9 . how many person died whose age was less then 40 
len(df[(df['Survived'] == 0) & (df['Age'] < 40)])
# Out:
# 322

# %%
#10 . from a  cabin column seperate text and numeric value .
import re
replace = re.compile("([a-zA-Z]+)")
df['string_cabin_list']=df['Cabin'].str.extract(replace)
df['num_cabin_list']=df['Cabin'].str.extract(replace,"")

# %%
df['string_cabin_list']
# Out:
# 0      NaN
# 1        C
# 2      NaN
# 3        C
# 4      NaN
#       ...
# 886    NaN
# 887      B
# 888    NaN
# 889      C
# 890    NaN
# Name: string_cabin_list, Length: 891, dtype: object

# %%
df2=pd.DataFrame(df.Cabin.str.split('([a-zA-Z]+)([^a-zA-Z]+)'))
df2
# Out:
#             Cabin
# 0             NaN
# 1     [, C, 85, ]
# 2             NaN
# 3    [, C, 123, ]
# 4             NaN
# ..            ...
# 886           NaN
# 887   [, B, 42, ]
# 888           NaN
# 889  [, C, 148, ]
# 890           NaN
#
# [891 rows x 1 columns]

# %%
df['cabin_Number']=df['Cabin'].str.replace('([a-zA-Z]+)','')
df['cabin_Letter']=df['Cabin'].str.extract('([a-zA-Z]+)')
# Out:
# C:\Users\ngupta\AppData\Local\Temp/ipykernel_18220/3059786258.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['cabin_Number']=df['Cabin'].str.replace('([a-zA-Z]+)','')

# %%
#1 . how many campaign available in this dataset . 
df11=pd.read_csv('C:\Users\ngupta\classes-ai\bank\bank.csv')
# Out:
#   File "C:\Users\ngupta\AppData\Local\Temp/ipykernel_18220/4066864606.py", line 2
#     df11=pd.read_csv('C:\Users\ngupta\classes-ai\bank\bank.csv')
#                                                                ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df11=pd.read_csv('C:\\Users\\ngupta\\classes-ai\\bank\\bank.csv')

# %%
df11.head()
# Out:
#   age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0  30;"unemployed";"married";"primary";"no";1787;...
# 1  33;"services";"married";"secondary";"no";4789;...
# 2  35;"management";"single";"tertiary";"no";1350;...
# 3  30;"management";"married";"tertiary";"no";1476...
# 4  59;"blue-collar";"married";"secondary";"no";0;...

# %%
df11['campaign']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Nitin\AI\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# C:\Nitin\AI\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\Nitin\AI\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'campaign'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df11=pd.read_csv('C:\\Users\\ngupta\\classes-ai\\bank\\bank.csv',sep=';')

# %%
df11.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
df11['campaign']
# Out:
# 0        1
# 1        1
# 2        1
# 3        4
# 4        1
#         ..
# 4516     5
# 4517     1
# 4518    11
# 4519     4
# 4520     2
# Name: campaign, Length: 4521, dtype: int64

# %%
df11['campaign'].unique()
# Out:
# array([ 1,  4,  2,  5,  3,  6, 18, 10,  9,  7, 12, 14, 13, 24, 11,  8, 29,
#        32, 16, 22, 15, 30, 25, 21, 17, 19, 23, 20, 50, 28, 31, 44],
#       dtype=int64)

# %%
len(df11['campaign'].unique())
# Out:
# 32

# %%
len(set(list(df11['campaign'])))
# Out:
# 32

# %%
#2 . how many users do we have with housing and personal loan .
df11[(df11['housing']=='yes') & (df11['loan']=='yes')]
# Out:
#       age            job  marital  education default  balance housing loan  \
# 1      33       services  married  secondary      no     4789     yes  yes
# 3      30     management  married   tertiary      no     1476     yes  yes
# 9      43       services  married    primary      no      -88     yes  yes
# 14     31    blue-collar  married  secondary      no      360     yes  yes
# 48     32   entrepreneur   single    primary     yes     -849     yes  yes
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4502   42       services  married  secondary      no      -91     yes  yes
# 4504   42    blue-collar   single  secondary      no     1080     yes  yes
# 4508   42         admin.  married    unknown      no      642     yes  yes
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
len(df11[(df11['housing']=='yes') & (df11['loan']=='yes')])
# Out:
# 406

# %%
#3. how many person do we have whose age is 60+ . 
len(df11[df11['age']>60])
# Out:
# 127

# %%
#4 . in which month we have trageted most of the customer .
df11["month"].value_counts()
# Out:
# may    1398
# jul     706
# aug     633
# jun     531
# nov     389
# apr     293
# feb     222
# jan     148
# oct      80
# sep      52
# mar      49
# dec      20
# Name: month, dtype: int64

# %%
df11["month"].value_counts().max()
# Out:
# 1398

# %%
df11["month"].value_counts().index
# Out:
# Index(['may', 'jul', 'aug', 'jun', 'nov', 'apr', 'feb', 'jan', 'oct', 'sep',
#        'mar', 'dec'],
#       dtype='object')

# %%
df11["month"].value_counts().index[0]
# Out:
# 'may'

# %%
#5 . which mode of call is giving you more result
df11.groupby(['contact','y'])

# %%
df11.groupby(['contact','y']).count()
# Out:
#                 age   job  marital  education  default  balance  housing  \
# contact   y
# cellular  no   2480  2480     2480       2480     2480     2480     2480
#           yes   416   416      416        416      416      416      416
# telephone no    257   257      257        257      257      257      257
#           yes    44    44       44         44       44       44       44
# unknown   no   1263  1263     1263       1263     1263     1263     1263
#           yes    61    61       61         61       61       61       61
#
#                loan   day  month  duration  campaign  pdays  previous  \
# contact   y
# cellular  no   2480  2480   2480      2480      2480   2480      2480
#           yes   416   416    416       416       416    416       416
# telephone no    257   257    257       257       257    257       257
#           yes    44    44     44        44        44     44        44
# unknown   no   1263  1263   1263      1263      1263   1263      1263
# ...

# %%
dfcellular=df11.groupby(['contact','y']).count()

# %%
dfcellular.loc['cellular']
# Out:
#       age   job  marital  education  default  balance  housing  loan   day  \
# y
# no   2480  2480     2480       2480     2480     2480     2480  2480  2480
# yes   416   416      416        416      416      416      416   416   416
#
#      month  duration  campaign  pdays  previous  poutcome
# y
# no    2480      2480      2480   2480      2480      2480
# yes    416       416       416    416       416       416

# %%
dfcellular.loc['cellular','yes']
# Out:
# age          416
# job          416
# marital      416
# education    416
# default      416
# balance      416
# housing      416
# loan         416
# day          416
# month        416
# duration     416
# campaign     416
# pdays        416
# previous     416
# poutcome     416
# Name: (cellular, yes), dtype: int64

# %%
dfcellular.loc['cellular','yes'][0]
# Out:
# 416

# %%
dfcellular.loc['unknown','yes'][0]
# Out:
# 61

# %%
dfcellular.loc['telephone','yes'][0]
# Out:
# 44

# %%
max(dfcellular.loc['cellular','yes'][0],dfcellular.loc['unknown','yes'][0] ,dfcellular.loc['telephone','yes'][0])
# Out:
# 416

# %%
#6 . how many enterpeures do we have in this list
df11.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
df11[df11['job']=='entrepreneur']
# Out:
#       age           job   marital  education default  balance housing loan  \
# 8      41  entrepreneur   married   tertiary      no      221     yes   no
# 23     44  entrepreneur   married  secondary      no       93      no   no
# 48     32  entrepreneur    single    primary     yes     -849     yes  yes
# 71     42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 150    41  entrepreneur   married    unknown      no       89     yes   no
# ...   ...           ...       ...        ...     ...      ...     ...  ...
# 4401   38  entrepreneur  divorced   tertiary      no     7929      no   no
# 4402   41  entrepreneur   married    primary      no       39     yes   no
# 4487   49  entrepreneur  divorced  secondary      no       32      no   no
# 4497   31  entrepreneur    single   tertiary      no       38      no   no
# 4520   44  entrepreneur    single   tertiary      no     1136     yes  yes
#
# ...

# %%
#7 . how many customers do we have with negative balance 
df11[df11.balance<0]
# Out:
#       age            job   marital  education default  balance housing loan  \
# 9      43       services   married    primary      no      -88     yes  yes
# 18     25    blue-collar    single    primary      no     -221     yes   no
# 48     32   entrepreneur    single    primary     yes     -849     yes  yes
# 60     41    blue-collar   married    primary      no     -516      no  yes
# 92     27       services    single  secondary      no     -195     yes   no
# ...   ...            ...       ...        ...     ...      ...     ...  ...
# 4474   44    blue-collar   married    primary      no     -237     yes   no
# 4502   42       services   married  secondary      no      -91     yes  yes
# 4506   42     unemployed  divorced   tertiary      no     -166      no   no
# 4516   33       services   married  secondary      no     -333     yes   no
# 4517   57  self-employed   married   tertiary     yes    -3313     yes  yes
#
# ...

# %%
#8. prepare a group of data based on education level . 
df11.groupby('education')

# %%
df11.groupby('education').count()
# Out:
#             age   job  marital  default  balance  housing  loan  contact  \
# education
# primary     678   678      678      678      678      678   678      678
# secondary  2306  2306     2306     2306     2306     2306  2306     2306
# tertiary   1350  1350     1350     1350     1350     1350  1350     1350
# unknown     187   187      187      187      187      187   187      187
#
#             day  month  duration  campaign  pdays  previous  poutcome     y
# education
# primary     678    678       678       678    678       678       678   678
# secondary  2306   2306      2306      2306   2306      2306      2306  2306
# tertiary   1350   1350      1350      1350   1350      1350      1350  1350
# unknown     187    187       187       187    187       187       187   187

# %%
df11.groupby('education')['education'].count()
# Out:
# education
# primary       678
# secondary    2306
# tertiary     1350
# unknown       187
# Name: education, dtype: int64

# %%
df11.education.unique()
# Out:
# array(['primary', 'secondary', 'tertiary', 'unknown'], dtype=object)

# %%
l=[]
for i in df11.education.unique():
    l.append(df11[df11["education"]==i])
    
l
# Out:
# [      age            job   marital education default  balance housing loan  \
#  0      30     unemployed   married   primary      no     1787      no   no
#  9      43       services   married   primary      no      -88     yes  yes
#  18     25    blue-collar    single   primary      no     -221     yes   no
#  26     55    blue-collar   married   primary      no      627     yes   no
#  36     78        retired  divorced   primary      no      229      no   no
#  ...   ...            ...       ...       ...     ...      ...     ...  ...
#  4480   23    blue-collar   married   primary      no     1158     yes   no
#  4485   53    blue-collar   married   primary      no      238     yes   no
#  4486   37    blue-collar   married   primary      no      378     yes   no
#  4499   45    blue-collar  divorced   primary      no      942      no   no
#  4503   60  self-employed   married   primary      no      362      no  yes
#
# ...

# %%
len(l)
# Out:
# 4

# %%
l[0]
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
# ...

# %%
l[1]
# Out:
#       age          job  marital  education default  balance housing loan  \
# 1      33     services  married  secondary      no     4789     yes  yes
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 7      39   technician  married  secondary      no      147     yes   no
# 10     39     services  married  secondary      no     9374     yes   no
# 11     43       admin.  married  secondary      no      264     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4515   32     services   single  secondary      no      473     yes   no
# 4516   33     services  married  secondary      no     -333     yes   no
# 4518   57   technician  married  secondary      no      295      no   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
#TASK
#read all resumes from ineuron git in pdf, word, and try to create a dataframe with resume name as a index value, 
#in column I am expecting email Id, linkedin id, Git Id, Skills as a result

# %%
import pandas as pd
import numpy as np #numeric python library, for any mathematical calculation

# %%
df12=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
#this will drop rows having any of NaN value even if single column has NaN value
#by default it drops rows and checks NaN row wise to drop
df12.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df12
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#you can see above it did not drop permanently and if you want to drop permanent then below is command
df12.dropna(inplace=True)

# %%
df12
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df12=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
#Now how to drop column wise records, so this will drop columns having any signle value as NaN
df12.dropna(axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df12.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#below you can see how many columns has null value which are dropped by dropna func
df12.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#drop only those columns which are having more than 10 null values
#thresh (threshold) is basically describe that it find 800 non-null values otherwise it drops those colums
df12.dropna(axis=1,thresh=800)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
#drop if all columns has all columns has null value
df12.dropna(axis=1,how='all')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#fill na with default provided value
df12.fillna(value="sudh")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df12.fillna(value=df12['Age'].mean())
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df12.groupby('Survived')

# %%
df12.groupby('Survived').describe()
# Out:
#          PassengerId                                                     \
#                count        mean         std  min     25%    50%    75%
# Survived
# 0              549.0  447.016393  260.640469  1.0  211.00  455.0  675.0
# 1              342.0  444.368421  252.358840  2.0  250.75  439.5  651.5
#
#                 Pclass            ... Parch        Fare                        \
#             max  count      mean  ...   75%  max  count       mean        std
# Survived                          ...
# 0         891.0  549.0  2.531876  ...   0.0  6.0  549.0  22.117887  31.388207
# 1         890.0  342.0  1.950292  ...   1.0  5.0  342.0  48.395408  66.596998
#
#
#           min      25%   50%   75%       max
# Survived
# 0         0.0   7.8542  10.5  26.0  263.0000
# 1         0.0  12.4750  26.0  57.0  512.3292
#
# [2 rows x 48 columns]

# %%
df12.groupby('Survived').describe()['PassengerId']
# Out:
#           count        mean         std  min     25%    50%    75%    max
# Survived
# 0         549.0  447.016393  260.640469  1.0  211.00  455.0  675.0  891.0
# 1         342.0  444.368421  252.358840  2.0  250.75  439.5  651.5  890.0

# %%
#.T is for transpose
df12.groupby('Survived').describe()['PassengerId'].T
# Out:
# Survived           0           1
# count     549.000000  342.000000
# mean      447.016393  444.368421
# std       260.640469  252.358840
# min         1.000000    2.000000
# 25%       211.000000  250.750000
# 50%       455.000000  439.500000
# 75%       675.000000  651.500000
# max       891.000000  890.000000

# %%
df12.groupby('Survived').describe()['PassengerId'].transpose()
# Out:
# Survived           0           1
# count     549.000000  342.000000
# mean      447.016393  444.368421
# std       260.640469  252.358840
# min         1.000000    2.000000
# 25%       211.000000  250.750000
# 50%       455.000000  439.500000
# 75%       675.000000  651.500000
# max       891.000000  890.000000

# %%
df13=pd.read_csv(r'C:\Users\ngupta\classes-ai\bank\bank.csv',sep=";")

# %%
l=[]
for i in df11.education.unique():
    l.append(df11[df11["education"]==i])

# %%
"sudh" + "kumar"
# Out:
# 'sudhkumar'

# %%
#concate data frames
l
# Out:
# [      age            job   marital education default  balance housing loan  \
#  0      30     unemployed   married   primary      no     1787      no   no
#  9      43       services   married   primary      no      -88     yes  yes
#  18     25    blue-collar    single   primary      no     -221     yes   no
#  26     55    blue-collar   married   primary      no      627     yes   no
#  36     78        retired  divorced   primary      no      229      no   no
#  ...   ...            ...       ...       ...     ...      ...     ...  ...
#  4480   23    blue-collar   married   primary      no     1158     yes   no
#  4485   53    blue-collar   married   primary      no      238     yes   no
#  4486   37    blue-collar   married   primary      no      378     yes   no
#  4499   45    blue-collar  divorced   primary      no      942      no   no
#  4503   60  self-employed   married   primary      no      362      no  yes
#
# ...

# %%
l[0]
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
# ...

# %%
type(l[0])
# Out:
# pandas.core.frame.DataFrame

# %%
dfconcat1=l[0]
dfconcat2=l[1]
dfconcat3=l[2]
dfconcat4=l[3]

# %%
len(dfconcat1)
# Out:
# 678

# %%
len(dfconcat2)
# Out:
# 2306

# %%
len(dfconcat3)
# Out:
# 1350

# %%
len(dfconcat4)
# Out:
# 187

# %%
dfconcat1.head()
# Out:
#     age          job   marital education default  balance housing loan  \
# 0    30   unemployed   married   primary      no     1787      no   no
# 9    43     services   married   primary      no      -88     yes  yes
# 18   25  blue-collar    single   primary      no     -221     yes   no
# 26   55  blue-collar   married   primary      no      627     yes   no
# 36   78      retired  divorced   primary      no      229      no   no
#
#       contact  day month  duration  campaign  pdays  previous poutcome    y
# 0    cellular   19   oct        79         1     -1         0  unknown   no
# 9    cellular   17   apr       313         1    147         2  failure   no
# 18    unknown   23   may       250         1     -1         0  unknown   no
# 26    unknown    5   may       247         1     -1         0  unknown   no
# 36  telephone   22   oct        97         1     -1         0  unknown  yes

# %%
dfconcat2.head()
# Out:
#     age          job  marital  education default  balance housing loan  \
# 1    33     services  married  secondary      no     4789     yes  yes
# 4    59  blue-collar  married  secondary      no        0     yes   no
# 7    39   technician  married  secondary      no      147     yes   no
# 10   39     services  married  secondary      no     9374     yes   no
# 11   43       admin.  married  secondary      no      264     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome   y
# 1   cellular   11   may       220         1    339         4  failure  no
# 4    unknown    5   may       226         1     -1         0  unknown  no
# 7   cellular    6   may       151         2     -1         0  unknown  no
# 10   unknown   20   may       273         1     -1         0  unknown  no
# 11  cellular   17   apr       113         2     -1         0  unknown  no

# %%
pd.concat([dfconcat1, dfconcat2])
# Out:
#       age          job   marital  education default  balance housing loan  \
# 0      30   unemployed   married    primary      no     1787      no   no
# 9      43     services   married    primary      no      -88     yes  yes
# 18     25  blue-collar    single    primary      no     -221     yes   no
# 26     55  blue-collar   married    primary      no      627     yes   no
# 36     78      retired  divorced    primary      no      229      no   no
# ...   ...          ...       ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar   married  secondary      no     1205     yes   no
# 4515   32     services    single  secondary      no      473     yes   no
# 4516   33     services   married  secondary      no     -333     yes   no
# 4518   57   technician   married  secondary      no      295      no   no
# 4519   28  blue-collar   married  secondary      no     1137      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
len(pd.concat([dfconcat1, dfconcat2]))
# Out:
# 2984

# %%
dfconcat2head =  dfconcat2.head()

# %%
dfconcat3head =  dfconcat3.head()

# %%
dfconcat2head
# Out:
#     age          job  marital  education default  balance housing loan  \
# 1    33     services  married  secondary      no     4789     yes  yes
# 4    59  blue-collar  married  secondary      no        0     yes   no
# 7    39   technician  married  secondary      no      147     yes   no
# 10   39     services  married  secondary      no     9374     yes   no
# 11   43       admin.  married  secondary      no      264     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome   y
# 1   cellular   11   may       220         1    339         4  failure  no
# 4    unknown    5   may       226         1     -1         0  unknown  no
# 7   cellular    6   may       151         2     -1         0  unknown  no
# 10   unknown   20   may       273         1     -1         0  unknown  no
# 11  cellular   17   apr       113         2     -1         0  unknown  no

# %%
dfconcat3head
# Out:
#    age            job  marital education default  balance housing loan  \
# 2   35     management   single  tertiary      no     1350     yes   no
# 3   30     management  married  tertiary      no     1476     yes  yes
# 5   35     management   single  tertiary      no      747      no   no
# 6   36  self-employed  married  tertiary      no      307     yes   no
# 8   41   entrepreneur  married  tertiary      no      221     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 5  cellular   23   feb       141         2    176         3  failure  no
# 6  cellular   14   may       341         1    330         2    other  no
# 8   unknown   14   may        57         2     -1         0  unknown  no

# %%
pd.concat([dfconcat2head, dfconcat3head]) #you can it is rowwise concatenation
# Out:
#     age            job  marital  education default  balance housing loan  \
# 1    33       services  married  secondary      no     4789     yes  yes
# 4    59    blue-collar  married  secondary      no        0     yes   no
# 7    39     technician  married  secondary      no      147     yes   no
# 10   39       services  married  secondary      no     9374     yes   no
# 11   43         admin.  married  secondary      no      264     yes   no
# 2    35     management   single   tertiary      no     1350     yes   no
# 3    30     management  married   tertiary      no     1476     yes  yes
# 5    35     management   single   tertiary      no      747      no   no
# 6    36  self-employed  married   tertiary      no      307     yes   no
# 8    41   entrepreneur  married   tertiary      no      221     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome   y
# 1   cellular   11   may       220         1    339         4  failure  no
# ...

# %%
#how to do column wise concatenation
pd.concat([dfconcat2head, dfconcat3head], axis=1)
# Out:
#      age          job  marital  education default  balance housing loan  \
# 1   33.0     services  married  secondary      no   4789.0     yes  yes
# 2    NaN          NaN      NaN        NaN     NaN      NaN     NaN  NaN
# 3    NaN          NaN      NaN        NaN     NaN      NaN     NaN  NaN
# 4   59.0  blue-collar  married  secondary      no      0.0     yes   no
# 5    NaN          NaN      NaN        NaN     NaN      NaN     NaN  NaN
# 6    NaN          NaN      NaN        NaN     NaN      NaN     NaN  NaN
# 7   39.0   technician  married  secondary      no    147.0     yes   no
# 8    NaN          NaN      NaN        NaN     NaN      NaN     NaN  NaN
# 10  39.0     services  married  secondary      no   9374.0     yes   no
# 11  43.0       admin.  married  secondary      no    264.0     yes   no
#
#      contact   day  ... loan   contact   day  month  duration campaign  pdays  \
# 1   cellular  11.0  ...  NaN       NaN   NaN    NaN       NaN      NaN    NaN
# ...

# %%
#lets narrow down the selection so that output can be verified
dfconcat2head_columns=dfconcat2head[['age','job','marital']]

# %%
dfconcat2head_columns
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %%
dfconcat3head_columns=dfconcat3head[['age','job','marital']]

# %%
dfconcat3head_columns
# Out:
#    age            job  marital
# 2   35     management   single
# 3   30     management  married
# 5   35     management   single
# 6   36  self-employed  married
# 8   41   entrepreneur  married

# %%
pd.concat([dfconcat2head_columns, dfconcat3head_columns], axis=1) #now you can see column wise concatenation
# Out:
#      age          job  marital   age            job  marital
# 1   33.0     services  married   NaN            NaN      NaN
# 2    NaN          NaN      NaN  35.0     management   single
# 3    NaN          NaN      NaN  30.0     management  married
# 4   59.0  blue-collar  married   NaN            NaN      NaN
# 5    NaN          NaN      NaN  35.0     management   single
# 6    NaN          NaN      NaN  36.0  self-employed  married
# 7   39.0   technician  married   NaN            NaN      NaN
# 8    NaN          NaN      NaN  41.0   entrepreneur  married
# 10  39.0     services  married   NaN            NaN      NaN
# 11  43.0       admin.  married   NaN            NaN      NaN

# %%
dfconcatresult = pd.concat([dfconcat2head_columns, dfconcat3head_columns], axis=1)

# %%
dfconcatresult
# Out:
#      age          job  marital   age            job  marital
# 1   33.0     services  married   NaN            NaN      NaN
# 2    NaN          NaN      NaN  35.0     management   single
# 3    NaN          NaN      NaN  30.0     management  married
# 4   59.0  blue-collar  married   NaN            NaN      NaN
# 5    NaN          NaN      NaN  35.0     management   single
# 6    NaN          NaN      NaN  36.0  self-employed  married
# 7   39.0   technician  married   NaN            NaN      NaN
# 8    NaN          NaN      NaN  41.0   entrepreneur  married
# 10  39.0     services  married   NaN            NaN      NaN
# 11  43.0       admin.  married   NaN            NaN      NaN

# %%
dfconcatresult['age']
# Out:
#      age   age
# 1   33.0   NaN
# 2    NaN  35.0
# 3    NaN  30.0
# 4   59.0   NaN
# 5    NaN  35.0
# 6    NaN  36.0
# 7   39.0   NaN
# 8    NaN  41.0
# 10  39.0   NaN
# 11  43.0   NaN

# %%
dfconcatresult.iloc[:,3] #select all rows and column wise i.e. 3rd index column here
# Out:
# 1      NaN
# 2     35.0
# 3     30.0
# 4      NaN
# 5     35.0
# 6     36.0
# 7      NaN
# 8     41.0
# 10     NaN
# 11     NaN
# Name: age, dtype: float64

# %%
dfconcatresult.iloc[:,[3,4]]
# Out:
#      age            job
# 1    NaN            NaN
# 2   35.0     management
# 3   30.0     management
# 4    NaN            NaN
# 5   35.0     management
# 6   36.0  self-employed
# 7    NaN            NaN
# 8   41.0   entrepreneur
# 10   NaN            NaN
# 11   NaN            NaN

# %%
dfconcatresult.iloc[[4,5],[3,4]] #fetch row index 4 and 5 from column index 3rd and 4th (index starts from 0)
# Out:
#     age            job
# 5  35.0     management
# 6  36.0  self-employed

# %%
dfconcatresult.loc[[4,5]]
# Out:
#     age          job  marital   age         job marital
# 4  59.0  blue-collar  married   NaN         NaN     NaN
# 5   NaN          NaN      NaN  35.0  management  single

# %%
dfconcatresult.loc[[4,5],['age']] #ilock take the default indexing and loc takes the named one indexing
# Out:
#     age   age
# 4  59.0   NaN
# 5   NaN  35.0

# %%
dfconcatresult.loc[[4,5],[3,4]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18220/236006096.py in <module>
# ----> 1 dfconcatresult.loc[[4,5],[3,4]]
#
# C:\Nitin\AI\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# C:\Nitin\AI\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1105         # ugly hack for GH #836
#    1106         if self._multi_take_opportunity(tup):
# -> 1107             return self._multi_take(tup)
#    1108
#    1109         return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
dfconcat2head_columns
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %%
dfconcat2head_columns.loc[[4,7],['job','marital']]
# Out:
#            job  marital
# 4  blue-collar  married
# 7   technician  married

# %%
dfconcat2head_columns.iloc[[1,2],[1,2]]
# Out:
#            job  marital
# 4  blue-collar  married
# 7   technician  married

# %%
dfconcat2head_columns.iloc[[1,2],[0,2]]
# Out:
#    age  marital
# 4   59  married
# 7   39  married

# %%
dfconcat2head_columns
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %%
dfconcat3head_columns
# Out:
#    age            job  marital
# 2   35     management   single
# 3   30     management  married
# 5   35     management   single
# 6   36  self-employed  married
# 8   41   entrepreneur  married

# %%
dfmerge=pd.merge(dfconcat2head_columns, dfconcat3head_columns)

# %%
dfmerge #why no result came? lets learn it
# Out:
# Empty DataFrame
# Columns: [age, job, marital]
# Index: []

# %%
dfmerge=pd.merge(dfconcat2head_columns, dfconcat3head_columns,on='age') #it does the inner join merge

# %%
dfmerge
# Out:
# Empty DataFrame
# Columns: [age, job_x, marital_x, job_y, marital_y]
# Index: []

# %%
dfmerge=pd.merge(dfconcat2head_columns, dfconcat3head_columns,on='marital')

# %%
dfmerge
# Out:
#     age_x        job_x  marital  age_y          job_y
# 0      33     services  married     30     management
# 1      33     services  married     36  self-employed
# 2      33     services  married     41   entrepreneur
# 3      59  blue-collar  married     30     management
# 4      59  blue-collar  married     36  self-employed
# 5      59  blue-collar  married     41   entrepreneur
# 6      39   technician  married     30     management
# 7      39   technician  married     36  self-employed
# 8      39   technician  married     41   entrepreneur
# 9      39     services  married     30     management
# 10     39     services  married     36  self-employed
# 11     39     services  married     41   entrepreneur
# 12     43       admin.  married     30     management
# 13     43       admin.  married     36  self-employed
# 14     43       admin.  married     41   entrepreneur

# %%
dfmerge=pd.merge(dfconcat2head_columns, dfconcat3head_columns,on='marital', how="left")

# %%
dfmerge
# Out:
#     age_x        job_x  marital  age_y          job_y
# 0      33     services  married     30     management
# 1      33     services  married     36  self-employed
# 2      33     services  married     41   entrepreneur
# 3      59  blue-collar  married     30     management
# 4      59  blue-collar  married     36  self-employed
# 5      59  blue-collar  married     41   entrepreneur
# 6      39   technician  married     30     management
# 7      39   technician  married     36  self-employed
# 8      39   technician  married     41   entrepreneur
# 9      39     services  married     30     management
# 10     39     services  married     36  self-employed
# 11     39     services  married     41   entrepreneur
# 12     43       admin.  married     30     management
# 13     43       admin.  married     36  self-employed
# 14     43       admin.  married     41   entrepreneur

# %%
pd.merge(dfconcat2head_columns, dfconcat3head_columns,on='marital', how="right")
# Out:
#     age_x        job_x  marital  age_y          job_y
# 0     NaN          NaN   single     35     management
# 1    33.0     services  married     30     management
# 2    59.0  blue-collar  married     30     management
# 3    39.0   technician  married     30     management
# 4    39.0     services  married     30     management
# 5    43.0       admin.  married     30     management
# 6     NaN          NaN   single     35     management
# 7    33.0     services  married     36  self-employed
# 8    59.0  blue-collar  married     36  self-employed
# 9    39.0   technician  married     36  self-employed
# 10   39.0     services  married     36  self-employed
# 11   43.0       admin.  married     36  self-employed
# 12   33.0     services  married     41   entrepreneur
# 13   59.0  blue-collar  married     41   entrepreneur
# 14   39.0   technician  married     41   entrepreneur
# 15   39.0     services  married     41   entrepreneur
# ...

# %%
pd.merge(dfconcat2head_columns, dfconcat3head_columns,on='marital', how="outer")
# Out:
#     age_x        job_x  marital  age_y          job_y
# 0    33.0     services  married     30     management
# 1    33.0     services  married     36  self-employed
# 2    33.0     services  married     41   entrepreneur
# 3    59.0  blue-collar  married     30     management
# 4    59.0  blue-collar  married     36  self-employed
# 5    59.0  blue-collar  married     41   entrepreneur
# 6    39.0   technician  married     30     management
# 7    39.0   technician  married     36  self-employed
# 8    39.0   technician  married     41   entrepreneur
# 9    39.0     services  married     30     management
# 10   39.0     services  married     36  self-employed
# 11   39.0     services  married     41   entrepreneur
# 12   43.0       admin.  married     30     management
# 13   43.0       admin.  married     36  self-employed
# 14   43.0       admin.  married     41   entrepreneur
# 15    NaN          NaN   single     35     management
# ...

# %%
dfconcat2head_columns
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %%
dfconcat3head_columns
# Out:
#    age            job  marital
# 2   35     management   single
# 3   30     management  married
# 5   35     management   single
# 6   36  self-employed  married
# 8   41   entrepreneur  married

# %%
dfconcat2head_columns.join(dfconcat3head_columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18220/3368841431.py in <module>
# ----> 1 dfconcat2head_columns.join(dfconcat3head_columns)
#
# C:\Nitin\AI\Anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9097         5  K5  A5  NaN
#    9098         """
# -> 9099         return self._join_compat(
#    9100             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9101         )
#
# C:\Nitin\AI\Anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9128                     sort=sort,
#    9129                 )
# -> 9130             return merge(
#    9131                 self,
#    9132                 other,
#
# ...

# %%
dfconcat2head_columns.join(dfconcat3head_columns,on="age")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18220/3459566040.py in <module>
# ----> 1 dfconcat2head_columns.join(dfconcat3head_columns,on="age")
#
# C:\Nitin\AI\Anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9097         5  K5  A5  NaN
#    9098         """
# -> 9099         return self._join_compat(
#    9100             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9101         )
#
# C:\Nitin\AI\Anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9128                     sort=sort,
#    9129                 )
# -> 9130             return merge(
#    9131                 self,
#    9132                 other,
#
# ...

# %%
dfconcat2head_columns.set_index('age')
# Out:
#              job  marital
# age
# 33      services  married
# 59   blue-collar  married
# 39    technician  married
# 39      services  married
# 43        admin.  married

# %%
dfconcat2head_columns
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %%
dfconcat2setindex=dfconcat2head_columns.set_index('age')

# %%
dfconcat2setindex
# Out:
#              job  marital
# age
# 33      services  married
# 59   blue-collar  married
# 39    technician  married
# 39      services  married
# 43        admin.  married

# %%
dfconcat2setindex.join(dfconcat3head_columns,on="age")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18220/4281328726.py in <module>
# ----> 1 dfconcat2setindex.join(dfconcat3head_columns,on="age")
#
# C:\Nitin\AI\Anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9097         5  K5  A5  NaN
#    9098         """
# -> 9099         return self._join_compat(
#    9100             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9101         )
#
# C:\Nitin\AI\Anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9128                     sort=sort,
#    9129                 )
# -> 9130             return merge(
#    9131                 self,
#    9132                 other,
#
# ...

# %%
dfconcat2setindex = dfconcat2setindex.rename(columns={'job':'job1', 'marital':'marital1'})

# %%
dfconcat2setindex
# Out:
#             job1 marital1
# age
# 33      services  married
# 59   blue-collar  married
# 39    technician  married
# 39      services  married
# 43        admin.  married

# %%
dfconcat2setindex.join(dfconcat3head_columns)
# Out:
#            job1 marital1  age  job marital
# 33     services  married  NaN  NaN     NaN
# 39   technician  married  NaN  NaN     NaN
# 39     services  married  NaN  NaN     NaN
# 43       admin.  married  NaN  NaN     NaN
# 59  blue-collar  married  NaN  NaN     NaN

# %%
dfconcat2setindex.join(dfconcat3head_columns,on='age')
# Out:
#             job1 marital1  age  job marital
# age
# 33      services  married  NaN  NaN     NaN
# 59   blue-collar  married  NaN  NaN     NaN
# 39    technician  married  NaN  NaN     NaN
# 39      services  married  NaN  NaN     NaN
# 43        admin.  married  NaN  NaN     NaN

# %%
dfconcat2setindex.join(dfconcat3head_columns,how="inner")
# Out:
# Empty DataFrame
# Columns: [job1, marital1, age, job, marital]
# Index: []

# %%
dfconcat2setindex.join(dfconcat3head_columns,how='right')
# Out:
#   job1 marital1  age            job  marital
# 2  NaN      NaN   35     management   single
# 3  NaN      NaN   30     management  married
# 5  NaN      NaN   35     management   single
# 6  NaN      NaN   36  self-employed  married
# 8  NaN      NaN   41   entrepreneur  married

# %%
dfconcat2setindex.join(dfconcat3head_columns,how='left')
# Out:
#            job1 marital1  age  job marital
# 33     services  married  NaN  NaN     NaN
# 39   technician  married  NaN  NaN     NaN
# 39     services  married  NaN  NaN     NaN
# 43       admin.  married  NaN  NaN     NaN
# 59  blue-collar  married  NaN  NaN     NaN

# %%
pd.merge(dfconcat2setindex,dfconcat3head_columns)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18220/1480368648.py in <module>
# ----> 1 pd.merge(dfconcat2setindex,dfconcat3head_columns)
#
# C:\Nitin\AI\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#
# C:\Nitin\AI\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     679             warnings.warn(msg, FutureWarning, stacklevel=3)
#     680
# --> 681         self._validate_specification()
#     682
# ...

# %%
dfconcat2setindex
# Out:
#             job1 marital1
# age
# 33      services  married
# 59   blue-collar  married
# 39    technician  married
# 39      services  married
# 43        admin.  married

# %%
dfconcat3head_columns
# Out:
#    age            job  marital
# 2   35     management   single
# 3   30     management  married
# 5   35     management   single
# 6   36  self-employed  married
# 8   41   entrepreneur  married

# %%
dfconcat3setindex=dfconcat3head_columns.set_index('age')

# %%
dfconcat3setindex
# Out:
#                job  marital
# age
# 35      management   single
# 30      management  married
# 35      management   single
# 36   self-employed  married
# 41    entrepreneur  married

# %%
dfconcat2setindex.join(dfconcat3setindex)
# Out:
#             job1 marital1  job marital
# age
# 33      services  married  NaN     NaN
# 39    technician  married  NaN     NaN
# 39      services  married  NaN     NaN
# 43        admin.  married  NaN     NaN
# 59   blue-collar  married  NaN     NaN

# %%
pd.merge(dfconcat2setindex,dfconcat3setindex)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18220/2996984136.py in <module>
# ----> 1 pd.merge(dfconcat2setindex,dfconcat3setindex)
#
# C:\Nitin\AI\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#
# C:\Nitin\AI\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     679             warnings.warn(msg, FutureWarning, stacklevel=3)
#     680
# --> 681         self._validate_specification()
#     682
# ...

# %%
pd.merge(dfconcat2setindex,dfconcat3setindex,left_on='job1',right_on='job')
# Out:
# Empty DataFrame
# Columns: [job1, marital1, job, marital]
# Index: []

# %%
pd.merge(dfconcat2setindex,dfconcat3setindex,left_on='job1',right_on='job',how="left")
# Out:
#           job1 marital1  job marital
# 0     services  married  NaN     NaN
# 1  blue-collar  married  NaN     NaN
# 2   technician  married  NaN     NaN
# 3     services  married  NaN     NaN
# 4       admin.  married  NaN     NaN

# %%
pd.merge(dfconcat2setindex,dfconcat3setindex,left_on='job1',right_on='job',how="right")
# Out:
#   job1 marital1            job  marital
# 0  NaN      NaN     management   single
# 1  NaN      NaN     management  married
# 2  NaN      NaN     management   single
# 3  NaN      NaN  self-employed  married
# 4  NaN      NaN   entrepreneur  married

# %%
dfconcat2setindex.reset_index()
# Out:
#    age         job1 marital1
# 0   33     services  married
# 1   59  blue-collar  married
# 2   39   technician  married
# 3   39     services  married
# 4   43       admin.  married

# %%
pd.merge(dfconcat2setindex.reset_index(),dfconcat3setindex.reset_index())
# Out:
# Empty DataFrame
# Columns: [age, job1, marital1, job, marital]
# Index: []

# %%
pd.merge(dfconcat2setindex.reset_index(),dfconcat3setindex.reset_index(),left_on='job1',right_on='job',how="right")
# Out:
#    age_x job1 marital1  age_y            job  marital
# 0    NaN  NaN      NaN     35     management   single
# 1    NaN  NaN      NaN     30     management  married
# 2    NaN  NaN      NaN     35     management   single
# 3    NaN  NaN      NaN     36  self-employed  married
# 4    NaN  NaN      NaN     41   entrepreneur  married

# %%
import requests
df=requests.get('https://github.com/iNeuronai/same-resume-year-wise')

# %%
df
# Out:
# <Response [200]>

# %%
type(df)
# Out:
# requests.models.Response

# %%
import pandas as pd

# %%
df=pd.read_html('https://github.com/iNeuronai/same-resume-year-wise')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12848/3026388730.py in <module>
# ----> 1 df=pd.read_html('https://github.com/iNeuronai/same-resume-year-wise')
#
# C:\Nitin\AI\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\Nitin\AI\Anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1096     io = stringify_path(io)
#    1097
# -> 1098     return _parse(
#    1099         flavor=flavor,
#    1100         io=io,
#
# ...
