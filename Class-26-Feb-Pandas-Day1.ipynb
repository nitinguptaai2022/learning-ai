# %%
#cassandra cloud datastax.com is not working that why install this but it local setup is not easy 
#so now continue with another session of pandas
# !pip install cassandra-driver

# %%
#pandas do the operations on structured data only not on unstructured data
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 182B-EBD8
#
#  Directory of C:\Users\ngupta\classes-ai
#
# 26-02-2022  11:55    <DIR>          .
# 26-02-2022  11:55    <DIR>          ..
# 26-02-2022  10:04    <DIR>          .ipynb_checkpoints
# 19-02-2022  18:15            15,508 Class-1.ipynb
# 21-02-2022  21:49            47,866 Class-2.ipynb
# 20-02-2022  14:45            42,194 Class-20-Feb.ipynb
# 26-02-2022  11:52             1,884 Class-26-Feb.ipynb
# 21-02-2022  23:06            40,720 Class-3.ipynb
# 22-02-2022  21:59            12,706 Class-4.ipynb
# 22-02-2022  22:47        18,982,290 Class-5.ipynb
# 23-02-2022  00:15             7,016 Class-6.ipynb
# 22-02-2022  21:59            25,286 for loops while loop.ipynb
# 22-02-2022  21:20            48,388 if else , for loop.ipynb
# 20-02-2022  11:03            12,288 india.db
# 20-02-2022  10:44             8,192 ineuron.db
# 20-02-2022  11:18            12,288 joindb.db
# ...

# %%
pd.read_csv('sample.csv')
# Out:
#    namename            emailid    address  pincode       sirname
# 0      sudh     sudh@gmail.com  Bangalore   560085         kumar
# 1     krish    krish@gmail.com      noida   200010          naik
# 2   ineuron  ineuron@gmail.com    chennai   256610  intellegence
# 3      name            emailid    address  pincode       sirname
# 4      sudh     sudh@gmail.com  Bangalore   560085         kumar
# 5     krish    krish@gmail.com      noida   200010          naik
# 6   ineuron  ineuron@gmail.com    chennai   256610  intellegence
# 7      name            emailid    address  pincode       sirname
# 8      sudh     sudh@gmail.com  Bangalore   560085         kumar
# 9     krish    krish@gmail.com      noida   200010          naik
# 10  ineuron  ineuron@gmail.com    chennai   256610  intellegence

# %%
pd.read_csv('C:\Nitin\AI\ohana-api-master\data\sample-csv\addresses.csv')
# Out:
#   File "C:\Users\ngupta\AppData\Local\Temp/ipykernel_2928/1192394024.py", line 1
#     pd.read_csv('C:\Nitin\AI\ohana-api-master\data\sample-csv\addresses.csv')
#                                                                             ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: malformed \N character escape

# %%
# used r to ignore the special character in file name or data
#data in output is called as dataframe
pd.read_csv(r'C:\Nitin\AI\ohana-api-master\data\sample-csv\addresses.csv')
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
df=pd.read_csv('sample.csv')

# %%
a=1

# %%
type(a)
# Out:
# int

# %%
#dataframe is a datatype in pandas which represents data
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv('samplewithoutheader.csv')
# Out:
#       sudh     sudh@gmail.com Unnamed: 2  Unnamed: 3    Unnamed: 4
# 0    krish    krish@gmail.com      noida      200010          naik
# 1  ineuron  ineuron@gmail.com    chennai      256610  intellegence
# 2     sudh     sudh@gmail.com  Bangalore      560085         kumar
# 3    krish    krish@gmail.com      noida      200010          naik
# 4  ineuron  ineuron@gmail.com    chennai      256610  intellegence
# 5     sudh     sudh@gmail.com  Bangalore      560085         kumar
# 6    krish    krish@gmail.com      noida      200010          naik
# 7  ineuron  ineuron@gmail.com    chennai      256610  intellegence

# %%
pd.read_csv('samplewithoutheader.csv',header=None)
# Out:
#          0                  1          2         3             4
# 0     sudh     sudh@gmail.com        NaN       NaN           NaN
# 1    krish    krish@gmail.com      noida  200010.0          naik
# 2  ineuron  ineuron@gmail.com    chennai  256610.0  intellegence
# 3     sudh     sudh@gmail.com  Bangalore  560085.0         kumar
# 4    krish    krish@gmail.com      noida  200010.0          naik
# 5  ineuron  ineuron@gmail.com    chennai  256610.0  intellegence
# 6     sudh     sudh@gmail.com  Bangalore  560085.0         kumar
# 7    krish    krish@gmail.com      noida  200010.0          naik
# 8  ineuron  ineuron@gmail.com    chennai  256610.0  intellegence

# %%
pd.read_csv('samplewithoutheader.csv',names=["col1","col2","col3","col4","col5"])
# Out:
#       col1               col2       col3      col4          col5
# 0     sudh     sudh@gmail.com        NaN       NaN           NaN
# 1    krish    krish@gmail.com      noida  200010.0          naik
# 2  ineuron  ineuron@gmail.com    chennai  256610.0  intellegence
# 3     sudh     sudh@gmail.com  Bangalore  560085.0         kumar
# 4    krish    krish@gmail.com      noida  200010.0          naik
# 5  ineuron  ineuron@gmail.com    chennai  256610.0  intellegence
# 6     sudh     sudh@gmail.com  Bangalore  560085.0         kumar
# 7    krish    krish@gmail.com      noida  200010.0          naik
# 8  ineuron  ineuron@gmail.com    chennai  256610.0  intellegence

# %%
pd.read_csv('samplewithoutheader.csv',names=["col1","col2","col3","col4","col5","col6"])
# Out:
#       col1               col2       col3      col4          col5  col6
# 0     sudh     sudh@gmail.com        NaN       NaN           NaN   NaN
# 1    krish    krish@gmail.com      noida  200010.0          naik   NaN
# 2  ineuron  ineuron@gmail.com    chennai  256610.0  intellegence   NaN
# 3     sudh     sudh@gmail.com  Bangalore  560085.0         kumar   NaN
# 4    krish    krish@gmail.com      noida  200010.0          naik   NaN
# 5  ineuron  ineuron@gmail.com    chennai  256610.0  intellegence   NaN
# 6     sudh     sudh@gmail.com  Bangalore  560085.0         kumar   NaN
# 7    krish    krish@gmail.com      noida  200010.0          naik   NaN
# 8  ineuron  ineuron@gmail.com    chennai  256610.0  intellegence   NaN

# %%
pd.read_csv('samplewithoutheader.csv',names=["col1","col2","col3","col4"])
# Out:
#                       col1       col2      col3          col4
# sudh        sudh@gmail.com        NaN       NaN           NaN
# krish      krish@gmail.com      noida  200010.0          naik
# ineuron  ineuron@gmail.com    chennai  256610.0  intellegence
# sudh        sudh@gmail.com  Bangalore  560085.0         kumar
# krish      krish@gmail.com      noida  200010.0          naik
# ineuron  ineuron@gmail.com    chennai  256610.0  intellegence
# sudh        sudh@gmail.com  Bangalore  560085.0         kumar
# krish      krish@gmail.com      noida  200010.0          naik
# ineuron  ineuron@gmail.com    chennai  256610.0  intellegence

# %%
#if less number columns are provided then starting less columns are treated as index columns
pd.read_csv('samplewithoutheader.csv',names=["col1","col2","col3"])
# Out:
#                                 col1      col2          col3
# sudh    sudh@gmail.com           NaN       NaN           NaN
# krish   krish@gmail.com        noida  200010.0          naik
# ineuron ineuron@gmail.com    chennai  256610.0  intellegence
# sudh    sudh@gmail.com     Bangalore  560085.0         kumar
# krish   krish@gmail.com        noida  200010.0          naik
# ineuron ineuron@gmail.com    chennai  256610.0  intellegence
# sudh    sudh@gmail.com     Bangalore  560085.0         kumar
# krish   krish@gmail.com        noida  200010.0          naik
# ineuron ineuron@gmail.com    chennai  256610.0  intellegence

# %%
pd.read_csv('sampletiledseparated.csv')
# Out:
#             namename~emailid~address~pincode~sirname
# 0         sudh~sudh@gmail.com~Bangalore~560085~kumar
# 1            krish~krish@gmail.com~noida~200010~naik
# 2  ineuron~ineuron@gmail.com~chennai~256610~intel...

# %%
pd.read_csv('sampletiledseparated.csv',delimiter='~')
# Out:
#   namename            emailid    address  pincode       sirname
# 0     sudh     sudh@gmail.com  Bangalore   560085         kumar
# 1    krish    krish@gmail.com      noida   200010          naik
# 2  ineuron  ineuron@gmail.com    chennai   256610  intellegence

# %%
pd.read_csv('sampletiledseparated.csv',sep='~')
# Out:
#   namename            emailid    address  pincode       sirname
# 0     sudh     sudh@gmail.com  Bangalore   560085         kumar
# 1    krish    krish@gmail.com      noida   200010          naik
# 2  ineuron  ineuron@gmail.com    chennai   256610  intellegence

# %%
df=pd.read_csv('sampletiledseparated.csv',sep='~')

# %%
df
# Out:
#   namename            emailid    address  pincode       sirname
# 0     sudh     sudh@gmail.com  Bangalore   560085         kumar
# 1    krish    krish@gmail.com      noida   200010          naik
# 2  ineuron  ineuron@gmail.com    chennai   256610  intellegence

# %%
df=pd.read_csv('sampletiledseparated.csv',sep='~', skiprows=[1,3])

# %%
df
# Out:
#   namename          emailid address  pincode sirname
# 0    krish  krish@gmail.com   noida   200010    naik

# %%
df1=pd.read_csv(r'C:\Nitin\AI\ohana-api-master\data\sample-csv\services.csv')

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
#this gives datatypes of each and every column from dataframe data
df1.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
#this shows you very first (from top) 5 records by default
df1.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
df1.head(2)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
#
#                   application_process  \
# 0          Walk in or apply by phone.
# 1  Apply by phone for an appointment.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
#
#                                          eligibility email  ...  \
# 0  Age 55 or over for most programs, age 60 or ov...   NaN  ...
# 1  Age 55 or over, county resident and willing an...   NaN  ...
#
#   interpretation_services                                           keywords  \
# ...

# %%
#this shows you last (from bottom) 5 records by default
df1.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
df1.tail(3)
# Out:
#     id  location_id  program_id         accepted_payments  \
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                application_process  \
# 20                    NaN    By phone during business hours.
# 21  Fotos para pasaportes  Walk in or apply by phone or mail
# 22                    NaN  Walk in or apply by phone or mail
#
#                                              audience  \
# 20                                                NaN
# 21  Profit and nonprofit businesses, the public, m...
# 22  Second service and nonprofit businesses, the p...
#
#                                           description eligibility  \
# 20                                just a test service         NaN
# 21  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...        None
# ...

# %%
#in jupyter notebook it is not possible to show all records, but it loads all obviously
df1
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
df1.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
df1.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df1.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
df1['service_areas']
# Out:
# 0                                     Colma
# 1                          San Mateo County
# 2                          San Mateo County
# 3                          San Mateo County
# 4                          San Mateo County
# 5                          San Mateo County
# 6       Belmont, Burlingame, East Palo Alto
# 7                   Belmont, East Palo Alto
# 8                          San Mateo County
# 9                          San Mateo County
# 10                         San Mateo County
# 11                                Daly City
# 12                         San Mateo County
# 13      Belmont, Burlingame, East Palo Alto
# 14         Alameda County, San Mateo County
# 15                                      NaN
# 16    Colma, Daly City, South San Francisco
# 17                           East Palo Alto
# 18                      Belmont, Burlingame
# 19                                      NaN
# 20                         San Mateo County
# ...

# %%
a=df1['service_areas']

# %%
a
# Out:
# 0                                     Colma
# 1                          San Mateo County
# 2                          San Mateo County
# 3                          San Mateo County
# 4                          San Mateo County
# 5                          San Mateo County
# 6       Belmont, Burlingame, East Palo Alto
# 7                   Belmont, East Palo Alto
# 8                          San Mateo County
# 9                          San Mateo County
# 10                         San Mateo County
# 11                                Daly City
# 12                         San Mateo County
# 13      Belmont, Burlingame, East Palo Alto
# 14         Alameda County, San Mateo County
# 15                                      NaN
# 16    Colma, Daly City, South San Francisco
# 17                           East Palo Alto
# 18                      Belmont, Burlingame
# 19                                      NaN
# 20                         San Mateo County
# ...

# %%
#pandas series datatype is equivalent to list of python but it is not called as list
#so series is a collection of number of rows with one column 
type(a)
# Out:
# pandas.core.series.Series

# %%
df1['service_areas']
# Out:
# 0                                     Colma
# 1                          San Mateo County
# 2                          San Mateo County
# 3                          San Mateo County
# 4                          San Mateo County
# 5                          San Mateo County
# 6       Belmont, Burlingame, East Palo Alto
# 7                   Belmont, East Palo Alto
# 8                          San Mateo County
# 9                          San Mateo County
# 10                         San Mateo County
# 11                                Daly City
# 12                         San Mateo County
# 13      Belmont, Burlingame, East Palo Alto
# 14         Alameda County, San Mateo County
# 15                                      NaN
# 16    Colma, Daly City, South San Francisco
# 17                           East Palo Alto
# 18                      Belmont, Burlingame
# 19                                      NaN
# 20                         San Mateo County
# ...

# %%
df1['service_areas','alternate_name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Nitin\AI\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# C:\Nitin\AI\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\Nitin\AI\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('service_areas', 'alternate_name')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df1[['service_areas','alternate_name']]
# Out:
#                             service_areas         alternate_name
# 0                                   Colma                    NaN
# 1                        San Mateo County                    NaN
# 2                        San Mateo County                    NaN
# 3                        San Mateo County                    NaN
# 4                        San Mateo County                    NaN
# 5                        San Mateo County                    NaN
# 6     Belmont, Burlingame, East Palo Alto                    NaN
# 7                 Belmont, East Palo Alto                    NaN
# 8                        San Mateo County                    NaN
# 9                        San Mateo County                    NaN
# 10                       San Mateo County                    NaN
# 11                              Daly City                    NaN
# 12                       San Mateo County                    NaN
# ...

# %%
a=df1[['service_areas','alternate_name']]

# %%
#this is little contradiction to above series example.
#so series will have one column and number of rows. 
#so double square bracket will give you dataframe as datatype
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df1[['service_areas']])
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_excel('C:\Nitin\AI\sample-excel-master\LUSID Excel - Manage Orders.xlsx')
# Out:
#   File "C:\Users\ngupta\AppData\Local\Temp/ipykernel_2928/2736607046.py", line 1
#     pd.read_excel('C:\Nitin\AI\sample-excel-master\LUSID Excel - Manage Orders.xlsx')
#                                                                                     ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: malformed \N character escape

# %%
pd.read_excel(r'C:\Nitin\AI\sample-excel-master\LUSID Excel - Manage Orders.xlsx')
# Out:
#     Unnamed: 0                               Unnamed: 1     Unnamed: 2  \
# 0          NaN  This sheet allows you to manage Orders:            NaN
# 1          NaN                            1. ListOrders            NaN
# 2          NaN                              2. Getorder            NaN
# 3          NaN                          3. UpsertOrders            NaN
# 4          NaN                                      NaN            NaN
# ..         ...                                      ...            ...
# 66         NaN                                      NaN            NaN
# 67         NaN                                      NaN            NaN
# 68         NaN                                      NaN           Code
# 69         NaN                                      NaN  MyOrderCode02
# 70         NaN                                      NaN  MyOrderCode01
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# ...

# %%
pd.read_excel(r'sample.xlsx',sheet_name="Allocations")
# Out:
#     Unnamed: 0                                    Unnamed: 1       Unnamed: 2  \
# 0          NaN  This sheet allows you to manage Allocations:              NaN
# 1          NaN                            1. ListAllocations              NaN
# 2          NaN                              2. GetAllocation              NaN
# 3          NaN                          3. UpsertAllocations              NaN
# 4          NaN                                           NaN              NaN
# ..         ...                                           ...              ...
# 60         NaN                                           NaN              NaN
# 61         NaN                                           NaN              NaN
# 62         NaN                                           NaN             Code
# 63         NaN                                           NaN  MyAllocation001
# 64         NaN                                           NaN  MyAllocation002
#
# ...

# %%
dfexcel=pd.read_excel(r'sample.xlsx',sheet_name="Allocations")

# %%
dfexcel.keys()
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21'],
#       dtype='object')

# %%
dfexcel=pd.ExcelFile('sample.xlsx')

# %%
dfexcel.sheet_names
# Out:
# ['Orders', 'Allocations', 'Placements', 'Blocks']

# %%
for i in dfexcel.sheet_names:
    print(i)
# Out:
# Orders
# Allocations
# Placements
# Blocks

# %%
pd.read_csv('https://github.com/datasciencedojo/datasets/blob/master/titanic.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2928/2188339314.py in <module>
# ----> 1 pd.read_csv('https://github.com/datasciencedojo/datasets/blob/master/titanic.csv')
#
# C:\Nitin\AI\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
pd.read_html('https://github.com/datasciencedojo/datasets/blob/master/titanic.csv')
# Out:
# [     Unnamed: 0  PassengerId  Survived  Pclass  \
#  0           NaN            1         0       3
#  1           NaN            2         1       1
#  2           NaN            3         1       3
#  3           NaN            4         1       1
#  4           NaN            5         0       3
#  ..          ...          ...       ...     ...
#  886         NaN          887         0       2
#  887         NaN          888         1       1
#  888         NaN          889         0       3
#  889         NaN          890         1       1
#  890         NaN          891         0       3
#
#                                                    Name     Sex   Age  SibSp  \
#  0                              Braund, Mr. Owen Harris    male  22.0      1
#  1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#  2                               Heikkinen, Miss. Laina  female  26.0      0
# ...

# %%
#it loaded because now we have give raw file URL, check diff from above url
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
